# %%
import traceback
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
from time import time
from datetime import datetime
import numpy as np
from sklearn.preprocessing import minmax_scale, MinMaxScaler
from scipy.stats import linregress
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
sns.set_style('ticks')

from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Conv1D, Input, Reshape, Dropout, LeakyReLU, MaxPooling1D, BatchNormalization
from keras.layers.recurrent import LSTM, GRU
from keras.optimizers import Adam, RMSprop, Nadam, SGD, Adagrad
from keras.utils import plot_model
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from keras.layers.merge import concatenate
from keras.initializers import RandomNormal

from hyperopt import Trials, STATUS_OK, tpe
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
def cnn_data():
    history_length = 30
    prediction_length = 10

    def frame_to_features(df, time_in, time_out):
        f = []
        n_features = len(df.columns)
        for i in range(time_in + 1, len(andf) - time_out):
            # reshape input to be 3D [samples, timesteps, features]
            f.append([minmax_scale(df.iloc[i - time_in:i].values), minmax_scale(df['Open'].iloc[i:i + time_out])])
        return f

    raw_df = pd.read_csv('data/history/ADABTC.csv')
    ndf = raw_df.filter(items=['Open', 'High', 'Low', 'Close', 'Volume', 'Number Trades', 'Quote Asset Volume', 'Taker Base Asset Volume', 'Taker Quote Asset Volume'])
    ndf = ndf.set_index(pd.to_datetime(raw_df['Open Time'], unit='ms'))
    ndf.dropna(inplace=True)
    andf = ndf
#     andf = ndf.apply(lambda c: minmax_scale(X=c, feature_range=(0, 1)))

    fs = frame_to_features(andf, history_length, prediction_length)

    # split into train and test sets
    train = np.array([x[0] for x in fs])
    test = np.array([x[1] for x in fs])
    # split into input and outputs
    train_X, test_X = np.array(train[:int(len(train) * 0.7)]), np.array(train[int(len(train) * 0.7):])
    train_y, test_y = np.array(test[:int(len(test) * 0.7)]), np.array(test[int(len(test) * 0.7):])

    return train_X, train_y, test_X, test_y

# %%
X_train, Y_train, X_test, Y_test = cnn_data()
print(X_train.shape, Y_train.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (29266, 30, 8) (29266, 10)
# (12543, 30, 8) (12543, 10)

# %%
def cnn_model(train_X, train_y, test_X, test_y, eps=50):
    prediction_length = 10

    #########################
    # MODEL PREP
    #########################
    
    rn = RandomNormal(mean=0.0, stddev=0.001)
    
    history_cnn_in = Input(shape=(train_X.shape[1], train_X.shape[2]))
    
#     history_cnn_out = Conv1D(filters=64, kernel_size=7, padding='valid', activation='tanh', kernel_initializer=rn)(history_cnn_in)
#     history_cnn_out = Conv1D(filters=32, kernel_size=5, padding='valid', activation='tanh', kernel_initializer=rn)(history_cnn_out)
#     history_cnn_out = Conv1D(filters=16, kernel_size=3, padding='valid', activation='tanh', kernel_initializer=rn)(history_cnn_out)
#     history_cnn_out = Conv1D(filters=8, kernel_size=3, padding='valid', activation='tanh', kernel_initializer=rn)(history_cnn_out)

    history_cnn_out = Flatten()(history_cnn_in)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/8), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/8), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/8), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/8), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/16), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/16), activation='linear', kernel_initializer=rn)(history_cnn_out)
    history_cnn_out = Dense(int(train_X.shape[1]*train_X.shape[2]/16), activation='linear', kernel_initializer=rn)(history_cnn_out)

    history_cnn_out = Dense(prediction_length, activation='linear', name='output', kernel_initializer=rn)(history_cnn_out)
    
    brain = Model(inputs=history_cnn_in, outputs=history_cnn_out)

    brain.compile(optimizer='adam', loss='mse', metrics=[])
    print(brain.summary())

    #########################
    # MODEL RUN
    #########################

    # fit network
#     TB = TensorBoard(log_dir='./TBlogs/' + datetime.now().strftime("%Y%m%d-%H%M%S"), histogram_freq=5, batch_size=64, write_graph=False, write_grads=True, write_images=True)
    reduceLR = ReduceLROnPlateau(monitor='val_loss', patience=3, verbose=1, factor=0.5, min_lr=0.00001)
    es = EarlyStopping(monitor='val_loss', min_delta=0, patience=5, verbose=1, mode='auto')
    
    history = brain.fit(train_X, train_y, epochs=eps, batch_size=8, validation_data=(test_X, test_y), verbose=1, shuffle=True, callbacks=[reduceLR, es])
    print(history.history['val_loss'][:-5])
    
    return brain

# %%
brain = cnn_model(X_train, Y_train, X_test, Y_test, eps=100)
print(brain.predict(X_test[:5]))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_22 (InputLayer)        (None, 30, 8)             0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 240)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 30)                7230
# _________________________________________________________________
# dense_79 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_80 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_81 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_82 (Dense)             (None, 15)                465
# ...

# %%
fig, ax = plt.subplots(figsize=(10, 4), dpi=120)
fig.legend()
l = 100
o = 50
pred = [np.nan]*l
bout = (brain.predict(X_test[o:o+1])[0])
print(X_test[o:o+5,0,0])
print(bout)
for e, p in enumerate(bout):
    pred[o+e] = p
ax.plot(range(l), X_test[:l,0,0], label='Real')
ax.plot(range(l), pred, label='Predicted')
plt.axvline(x=o, c='r')
# Out:
# No handles with labels found to put in legend.
# [1.         0.89320388 0.86407767 0.75728155 0.63106796]
# [0.5178371  0.51256925 0.508942   0.5024904  0.49951372 0.49603808
#  0.49372965 0.48661077 0.48067525 0.47870123]

# %% [markdown]
# # RNN

# %%
def rnn_data():
    history_length = 30
    prediction_length = 10

    raw_df = pd.read_csv('data/history/ADABTC.csv')
    ndf = raw_df.filter(items=['Open', 'High', 'Low', 'Close', 'Volume', 'Number Trades', 'Quote Asset Volume', 'Taker Base Asset Volume', 'Taker Quote Asset Volume'])
    ndf = ndf.set_index(pd.to_datetime(raw_df['Open Time'], unit='ms'))
    ndf.dropna(inplace=True)
    scaler = MinMaxScaler(feature_range = (0, 1))
    sndf = scaler.fit_transform(ndf)

    TRAIN_SIZE = 0.60

    train_size = int(len(sndf) * TRAIN_SIZE)
    test_size = len(sndf) - train_size
    train, test = sndf[0:train_size, :], dataset[train_size:len(dataset), :]

    return train_X, train_y, test_X, test_y, scaler
