# %%
import pandas as pd
from time import time
from datetime import datetime
import numpy as np
from sklearn.preprocessing import minmax_scale, MinMaxScaler
from scipy.stats import linregress
from matplotlib import pyplot
import seaborn as sns
sns.set_style('ticks')

from keras.models import Sequential, Model
from keras.layers import Flatten, Dense, Conv1D, Input, Reshape, Dropout, LeakyReLU, MaxPooling1D
from keras.optimizers import Adam, RMSprop, Nadam, SGD, Adagrad
from keras.utils import plot_model
from keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from keras.layers.merge import concatenate
# Out:
# /Users/tkind/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
raw_df = pd.read_csv('data/history/ADABTC.csv')
raw_df.head()
# Out:
#        Open Time      Open      High       Low     Close   Volume  \
# 0  1516402800000  0.000056  0.000056  0.000056  0.000056  97448.0
# 1  1516403100000  0.000056  0.000056  0.000056  0.000056  65878.0
# 2  1516403400000  0.000056  0.000056  0.000056  0.000056  54614.0
# 3  1516403700000  0.000056  0.000056  0.000056  0.000056  62223.0
# 4  1516404000000  0.000056  0.000056  0.000056  0.000056  64601.0
#
#       Close Time  Quote Asset Volume  Number Trades  Taker Base Asset Volume  \
# 0  1516403099999            5.475902            123                  48352.0
# 1  1516403399999            3.699381            108                  40093.0
# 2  1516403699999            3.064731            102                  24254.0
# 3  1516403999999            3.492357            114                  44992.0
# 4  1516404299999            3.628620             92                  33380.0
#
#    Take Quote Asset Volume  Ignore
# 0                 2.718388       0
# ...

# %%
ndf = raw_df.filter(items=['Open', 'High', 'Low', 'Close', 'Volume', 'Number Trades', 'Quote Asset Volume', 'Taker Base Asset Volume', 'Taker Quote Asset Volume'])
ndf = ndf.set_index(pd.to_datetime(raw_df['Open Time'],unit='ms'))
ndf.dropna(inplace=True)

# %%
# specify columns to plot
cols = ndf.columns
i = 1
# plot each column
pyplot.figure(figsize=(30, 10), dpi=400)
pyplot.subplots_adjust(hspace = 1)
for col in cols:
    pyplot.subplot(len(cols), 1, i)
    pyplot.plot(ndf[col])
    pyplot.title(col, y=1, loc='left')
    i += 1
pyplot.show()

# %%
andf = ndf.apply(lambda c: minmax_scale(X=c, feature_range=(0, 1)))
# Out:
# /Users/tkind/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64.
#   warnings.warn(msg, DataConversionWarning)

# %%
def frame_to_features(df, time_in, time_out):
    f = []
    n_features = len(df.columns)
    for i in range(time_in+1, len(andf)-time_out):
        # reshape input to be 3D [samples, timesteps, features]
        f.append([
            df.iloc[i - time_in:i].values,
            #             df['Open'].iloc[i - time_out + 2:i + 2].values
            (df['Open'].iloc[i+time_out-1] > df['Open'].iloc[i+time_out])
        ])
    return f

# %%
history_length = 50
prediction_length = 1
fs = frame_to_features(andf, history_length, prediction_length)

# %%
# split into train and test sets
train = [x[0] for x in fs]
test = [x[1] for x in fs]
# split into input and outputs
train_X, test_X = np.array(train[:int(len(train)*0.7)]), np.array(train[int(len(train)*0.7):])
train_y = np.array(test[:int(len(test)*0.7)])
test_y  = np.array(test[int(len(test)*0.7):])

# %%
optimizer = Adagrad(lr=0.01, clipvalue=2)


def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr

    return lr


lr_metric = get_lr_metric(optimizer)

# %%
try:
    print(brain.sumarry())
except:
    kernel_length = int(history_length/5)

    history_cnn_input = Input(shape=(train_X.shape[1], train_X.shape[2]))
    history_cnn_out = Conv1D(filters=256, kernel_size=kernel_length, padding='same', activation='relu')(history_cnn_input)
    history_cnn_out = MaxPooling1D(pool_size=3)(history_cnn_out)
    history_cnn_out = Conv1D(filters=128, kernel_size=kernel_length, padding='same', activation='relu')(history_cnn_out)
    history_cnn_out = MaxPooling1D(pool_size=3)(history_cnn_out)
    history_cnn_out = Conv1D(filters=64, kernel_size=kernel_length, padding='same', activation='relu')(history_cnn_out)
    history_cnn_out = MaxPooling1D(pool_size=3)(history_cnn_out)
    history_cnn_out = Conv1D(filters=32, kernel_size=kernel_length, padding='same', activation='relu')(history_cnn_out)
    history_cnn_out = Conv1D(filters=16, kernel_size=kernel_length, padding='same', activation='relu')(history_cnn_out)
    history_cnn_out = Flatten()(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 4), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 3), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 2), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 1), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 1), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(max(int(history_length * 0.3), 10), activation='relu')(history_cnn_out)
    history_cnn_out = Dense(prediction_length, activation='linear')(history_cnn_out)
    brain = Model(input=history_cnn_input, output=history_cnn_out)
    
    brain.compile(optimizer = optimizer, loss='mse', metrics=['mape', 'mae', 'mse', lr_metric])
    brain.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 50, 8)             0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 50, 256)           20736
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 16, 256)           0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 16, 128)           327808
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 5, 128)            0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 5, 64)             81984
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 1, 64)             0
# ...

# %%
# fit network
TB = TensorBoard(log_dir='./TBlogs/'+ datetime.now().strftime("%Y%m%d-%H%M%S"), histogram_freq=5, batch_size=64, write_graph=False, write_grads=True, write_images=True)

# reduceLR = ReduceLROnPlateau(monitor='loss', patience=1, verbose=1, factor=0.1, min_lr=0.0001)
brain.fit(train_X, train_y, epochs=10, batch_size=16, validation_data=(test_X, test_y), verbose=1, shuffle=True, callbacks=[TB])
# Out:
# Train on 29258 samples, validate on 12540 samples
# Epoch 1/10
# 29258/29258 [==============================] - 31s 1ms/step - loss: 0.2502 - mean_absolute_percentage_error: 248944993.3146 - mean_absolute_error: 0.4983 - mean_squared_error: 0.2502 - lr: 0.0100 - val_loss: 0.2487 - val_mean_absolute_percentage_error: 252708672.2552 - val_mean_absolute_error: 0.4978 - val_mean_squared_error: 0.2487 - val_lr: 0.0100
# Epoch 2/10
# 29258/29258 [==============================] - 29s 986us/step - loss: 0.2500 - mean_absolute_percentage_error: 249320371.2166 - mean_absolute_error: 0.4985 - mean_squared_error: 0.2500 - lr: 0.0100 - val_loss: 0.2487 - val_mean_absolute_percentage_error: 243855406.7394 - val_mean_absolute_error: 0.4966 - val_mean_squared_error: 0.2487 - val_lr: 0.0100
# Epoch 3/10
# ...

# %%
i = 10000
yhat = brain.predict(test_X[i].reshape(1, history_length, -1))
print(test_y[i], yhat)
print(((test_y[i]-yhat)/test_y[i])*100)
# Out:
# False [[0.46570218]]
# [[-inf]]
# /Users/tkind/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in true_divide
#   after removing the cwd from sys.path.
